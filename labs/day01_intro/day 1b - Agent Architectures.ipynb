# %% [markdown]
# # 🚀 Multi-Agent Systems & Workflow Patterns
#
# **Welcome to the Kaggle 5-day Agents course!**
#
# In the previous notebook, you built a **single agent** that could take action. Now, you'll learn how to scale up by building **agent teams**.
#
# Just like a team of people, you can create specialized agents that collaborate to solve complex problems. This is called a **multi-agent system**, and it's one of the most powerful concepts in AI agent development.
#
# In this notebook, you'll:
#
# - ✅ Learn when to use multi-agent systems in [Agent Development Kit (ADK)](https://google.github.io/adk-docs/)
# - ✅ Build your first system using an LLM as a "manager"
# - ✅ Learn three core workflow patterns (Sequential, Parallel, and Loop) to coordinate your agent teams

# %% [markdown]
# ## ⚙️ Section 1: Setup

# %%
#create venv
# python -m venv venv
#activate venv
# .\venv\Scripts\activate
#install dependencies
# pip install -r requirements.txt

# %%
# authentication setup
import os
from dotenv import load_dotenv

# laod .env file from root directory which has the API key
load_dotenv('../../.env')

try:
    GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
    if GOOGLE_API_KEY is None:
        raise ValueError("GOOGLE_API_KEY not found in environment variables.")
    os.environ['GOOGLE_API_KEY'] = GOOGLE_API_KEY
    print("GOOGLE_API_KEY successfully set.")
except Exception as e:
   print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your .env file. Details: {e}"
    )
# Out:
# GOOGLE_API_KEY successfully set.

# %%
#import ADK components
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Configure Retry Options
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# ## 🤔 Section 2: Why Multi-Agent Systems?

# %% [markdown]
# Instead of one "do-it-all" agent, we can build a **multi-agent system**. This is a team of simple, specialized agents that collaborate, just like a real-world team. Each agent has one clear job (e.g., one agent *only* does research, another *only* writes). This makes them easier to build, easier to test, and much more powerful and reliable when working together.
#
# To learn more, check out the documentation related to [LLM agents in ADK](https://google.github.io/adk-docs/agents/llm-agents/).
#
#
# **Architecture: Single Agent vs Multi-Agent Team**
#
#
# ```mermaid
# graph TD
#     subgraph Single["❌ Monolithic Agent"]
#         A["One Agent Does Everything"]
#     end
#
#
#     subgraph Multi["✅ Multi-Agent Team"]
#         B["Root Coordinator"] --> C["Research Specialist"]
#         B --> E["Summary Specialist"]
#
#
#         C -->|findings| F["Shared State"]
#         E -->|summary| F
#     end
#
#
#     style A fill:#ffffff,stroke:#000,color:#000
#     style B fill:#ffffff,stroke:#000,color:#000
#     style C fill:#ffffff,stroke:#000,color:#000
#     style E fill:#ffffff,stroke:#000,color:#000
#     style F fill:#ffffff,stroke:#000,color:#000
# ```

# %% [markdown]
# ### 2.1 Example: Research & Summarization System
#
# Let's build a system with two specialized agents:
#
# 1. **Research Agent** - Searches for information using Google Search
# 2. **Summarizer Agent** - Creates concise summaries from research findings

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# We bring the agents together under a root agent or coordinator.

# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# ResearchCoordinator > The latest advancements in quantum computing are poised to revolutionize AI by offering unprecedented computational power through qubits, leading to significantly faster AI model training and improved optimization. AI itself is also contributing to quantum computing by aiding in error correction, with hybrid quantum-classical systems representing a key development pathway. Continuous progress in quantum hardware is fundamental to unlocking these transformative capabilities, which are expected to impact numerous industries despite some remaining compatibility challenges between the two fields.

# %% [markdown]
# ## 🚥 Section 3: Sequential Workflows - The Assembly Line
#
# **The Problem: Unpredictable Order**
#
# The previous multi-agent system worked, but it relied on a **detailed instruction prompt** to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.
#
# **The Solution: A Fixed Pipeline**
#
# When you need tasks to happen in a **guaranteed, specific order**, you can use a `SequentialAgent`. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# **Use Sequential when:** Order matters, you need a linear pipeline, or each step builds on the previous one.
#
# To learn more, check out the documentation related to [sequential agents in ADK](https://google.github.io/adk-docs/agents/workflow-agents/sequential-agents/).
#
# **Architecture: Blog Post Creation Pipeline**
#
#
# ```mermaid
# graph LR
#     A["User Input: Blog about AI"] --> B["Outline Agent"]
#     B -->|blog_outline| C["Writer Agent"]
#     C -->|blog_draft| D["Editor Agent"]
#     D -->|final_blog| E["Output"]
#
#     style B fill:#ffcccc
#     style C fill:#ccffcc
#     style D fill:#ccccff
# ```

# %% [markdown]
# ### 3.1 Example: Blog Post Creation with Sequential Agents
#
# Let's build a system with three specialized agents:
#
# 1. **Outline Agent** - Creates a blog outline for a given topic
# 2. **Writer Agent** - Writes a blog post
# 3. **Editor Agent** - Edits a blog post draft for clarity and structure

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
# bring all the agents together under a sequential agent
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Here is a blog outline about the benefits of multi-agent systems for software developers:
#
# ## Unleash Your Code's Potential: How Multi-Agent Systems Empower Developers
#
# **Introduction Hook:** Ever feel like your software is a lone wolf, struggling to tackle complex problems? What if you could build systems composed of intelligent, independent agents, each contributing to a larger goal? Welcome to the world of multi-agent systems (MAS), a paradigm shift that's revolutionizing how we develop software and unlocking powerful new capabilities.
#
# ---
#
# **Main Section 1: Enhanced Problem Solving and Complexity Management**
#
# *   **Decomposition for Clarity:** Break down large, intricate problems into smaller, manageable sub-problems, with each agent handling a specific task. This makes the overall system easier to understand, design, and debug.
# *   **Distributed Intelligence:** Leverage the collective intelligence of multiple agents. If one agent encounters an issue or is overloaded, others can potentially step in or adapt, leading to more robust and resilient solutions.
# *   **Specialization and Efficiency:** Allow agents to specialize in specific domains or algorithms. This focused expertise can lead to more efficient processing and higher quality outputs compared to a monolithic system trying to do everything.
#
# **Main Section 2: Improved Adaptability and Resilience**
#
# *   **Dynamic Reconfiguration:** MAS can adapt to changing environments or requirements. New agents can be introduced, existing ones modified, or even removed dynamically without bringing the entire system down.
# *   **Fault Tolerance:** The distributed nature of MAS inherently provides fault tolerance. If a single agent fails, the system can continue to operate, albeit potentially with reduced functionality, rather than collapsing entirely.
# *   **Graceful Degradation:** Instead of outright failure, a MAS can exhibit graceful degradation. As resources diminish or components fail, the system can intelligently scale back its operations to maintain essential functions.
#
# **Main Section 3: Fostering Collaboration and Interoperability**
#
# *   **Agent Communication and Coordination:** Design agents that can communicate and coordinate their actions effectively. This enables sophisticated teamwork and the tackling of problems that require synchronized efforts.
# *   **Interoperability Between Diverse Systems:** MAS provide a framework for integrating disparate software systems and services. Agents can act as bridges, translating and coordinating interactions between systems with different protocols or data formats.
# *   **Emergent Behavior:** Observe how simple agent interactions can lead to complex and often unexpected emergent behaviors. This can be a powerful tool for discovering novel solutions or optimizing system performance in ways that might not have been explicitly programmed.
#
# ---
#
# **Concluding Thought:** Embracing multi-agent systems isn't just about adopting a new architectural style; it's about fundamentally rethinking how we approach software development. By empowering developers with tools for decomposition, adaptability, and intelligent collaboration, MAS offer a pathway to building more intelligent, resilient, and powerful software than ever before. So, are you ready to let your code team up and conquer complexity?
# WriterAgent > ## Unleash Your Code's Potential: How Multi-Agent Systems Empower Developers
#
# Ever feel like your software is a lone wolf, struggling to tackle complex problems? What if you could build systems composed of intelligent, independent agents, each contributing to a larger goal? Welcome to the world of multi-agent systems (MAS), a paradigm shift that's revolutionizing how we develop software and unlocking powerful new capabilities.
#
# One of the most significant advantages of MAS lies in **enhanced problem-solving and complexity management**. Imagine breaking down a giant, daunting task into smaller, digestible pieces. With MAS, you can assign each piece to a specialized agent. This decomposition makes your system easier to understand, design, and debug. Furthermore, you leverage **distributed intelligence**; if one agent falters, others can adapt, leading to more robust solutions. Plus, agents can **specialize**, leading to greater efficiency and higher-quality outputs than a single, overloaded monolithic system.
#
# MAS also dramatically improve **adaptability and resilience**. Think of a system that can reconfigure itself on the fly. New agents can be added, or existing ones modified, without bringing the whole operation down. The distributed nature provides inherent **fault tolerance** – if one agent fails, the system can continue functioning, perhaps with reduced capacity, rather than collapsing entirely. This allows for **graceful degradation**, a far better outcome than outright failure.
#
# Finally, MAS foster **collaboration and interoperability**. By designing agents that can communicate and coordinate, you enable sophisticated teamwork. This is invaluable for tackling problems requiring synchronized efforts. MAS also act as bridges, integrating **diverse systems** by translating and coordinating interactions. You might even witness fascinating **emergent behaviors** from simple agent interactions, leading to novel solutions!
#
# Embracing multi-agent systems means rethinking software development. It’s about empowering your code to team up, conquer complexity, and build more intelligent, resilient, and powerful software. Are you ready to unleash your code's full potential?
# EditorAgent > ## Unleash Your Code's Potential: How Multi-Agent Systems Empower Developers
#
# Does your software often feel like a lone wolf, struggling to tackle complex problems? Imagine building systems composed of intelligent, independent agents, each contributing to a larger goal. Welcome to the world of Multi-Agent Systems (MAS) – a paradigm shift that's revolutionizing software development and unlocking powerful new capabilities.
#
# One of the most significant advantages of MAS lies in **enhanced problem-solving and complexity management**. Think about breaking down a giant, daunting task into smaller, more digestible pieces. With MAS, you can assign each piece to a specialized agent. This decomposition makes your system easier to understand, design, and debug. Furthermore, you harness **distributed intelligence**; if one agent falters, others can adapt, leading to more robust solutions. Agents can also **specialize**, resulting in greater efficiency and higher-quality outputs than a single, overloaded monolithic system could achieve.
#
# MAS also dramatically improve **adaptability and resilience**. Consider a system that can reconfigure itself on the fly. New agents can be added, or existing ones modified, without bringing the entire operation to a halt. The distributed nature provides inherent **fault tolerance** – if one agent fails, the system can continue functioning, perhaps with reduced capacity, rather than collapsing entirely. This allows for **graceful degradation**, a far better outcome than outright failure.
#
# Finally, MAS foster **collaboration and interoperability**. By designing agents that can communicate and coordinate, you enable sophisticated teamwork. This is invaluable for tackling problems that require synchronized efforts. MAS also act as bridges, integrating **diverse systems** by translating and coordinating interactions. You might even witness fascinating **emergent behaviors** arising from simple agent interactions, leading to novel solutions!
#
# Embracing multi-agent systems means rethinking software development. It’s about empowering your code to team up, conquer complexity, and build more intelligent, resilient, and powerful software. Are you ready to unleash your code's full potential?

# %% [markdown]
# ---
# ## 🛣️ Section 4: Parallel Workflows - Independent Researchers
#
# **The Problem: The Bottleneck**
#
# The previous sequential agent is great, but it's an assembly line. Each step must wait for the previous one to finish. What if you have several tasks that are **not dependent** on each other? For example, researching three *different* topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# **The Solution: Concurrent Execution**
#
# When you have independent tasks, you can run them all at the same time using a `ParallelAgent`. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.
#
# **Use Parallel when:** Tasks are independent, speed matters, and you can execute concurrently.
#
# To learn more, check out the documentation related to [parallel agents in ADK](https://google.github.io/adk-docs/agents/workflow-agents/parallel-agents/).
#
# **Architecture: Multi-Topic Research**
#
# ```mermaid
# graph TD
#     A["User Request: Research 3 topics"] --> B["Parallel Execution"]
#     B --> C["Tech Researcher"]
#     B --> D["Health Researcher"]
#     B --> E["Finance Researcher"]
#
#     C --> F["Aggregator"]
#     D --> F
#     E --> F
#     F --> G["Combined Report"]
#
#     style B fill:#ffffcc
#     style F fill:#ffccff
# ```

# %% [markdown]
# ### 4.1 Example: Parallel Multi-Topic Research
#
# Let's build a system with four agents:
#
# 1. **Tech Researcher** - Researches AI/ML news and trends
# 2. **Health Researcher** - Researches recent medical news and trends
# 3. **Finance Researcher** - Researches finance and fintech news and trends
# 4. **Aggregator Agent** - Combines all research findings into a single summary

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# OutlineAgent > Here's a blog outline for your request:
#
# ## Headline: The Daily Dose: Tech, Health, & Finance Insights You Can't Afford to Miss
#
# ### Introduction Hook:
#
# *   In today's fast-paced world, staying informed is paramount. But with information overload, where do you find the crucial updates that impact your life and work? This daily briefing cuts through the noise, delivering the essential news from the buzzing worlds of technology, the ever-evolving landscape of health, and the dynamic currents of finance.
#
# ### Section 1: Tech Trends to Track
#
# *   **AI's Next Frontier:** Exploring the latest advancements in generative AI, from new creative tools to its potential impact on various industries and ethical considerations.
# *   **Cybersecurity at the Forefront:** Examining recent major cyber threats, emerging defense strategies, and the ongoing arms race between attackers and defenders.
# *   **The Metaverse & Web3 Evolution:** What's new in the decentralized web and immersive digital spaces? Discussing key developments, user adoption, and potential future applications.
#
# ### Section 2: Health Headlines Shaping Our Future
#
# *   **Breakthroughs in Biotech:** Highlighting significant discoveries in gene editing, personalized medicine, and novel drug development that promise to revolutionize healthcare.
# *   **Public Health Pulse Check:** Analyzing current trends in global health, from infectious disease outbreaks to the ongoing impact of lifestyle factors on chronic conditions.
# *   **Wellness Tech Innovations:** Discovering how wearable devices, AI-powered diagnostics, and digital health platforms are empowering individuals to take control of their well-being.
#
# ### Section 3: Finance Focus: Markets & Money Matters
#
# *   **Economic Indicators to Watch:** Decoding the latest inflation data, interest rate decisions, and key economic reports that are influencing global markets.
# *   **Investment Landscape Shifts:** Understanding emerging investment opportunities, the performance of different asset classes, and expert outlooks for the coming weeks.
# *   **Financial Policy & Regulation Updates:** Keeping you informed on new governmental policies, regulatory changes, and their potential impact on businesses and individual finances.
#
# ### Conclusion:
#
# *   The confluence of technology, health, and finance creates a complex but exciting ecosystem. By staying informed on these daily shifts, you're better equipped to navigate challenges, seize opportunities, and make smarter decisions in both your personal and professional life. Let this briefing be your compass in the ever-changing currents of innovation and progress.
# WriterAgent > ## The Daily Dose: Tech, Health, & Finance Insights You Can't Afford to Miss
#
# In today's fast-paced world, staying informed is paramount. But with information overload, where do you find the crucial updates that impact your life and work? This daily briefing cuts through the noise, delivering the essential news from the buzzing worlds of technology, the ever-evolving landscape of health, and the dynamic currents of finance.
#
# **Tech Trends to Track:** Generative AI continues its rapid ascent, with new creative tools emerging and discussions intensifying around its industry-wide impact and ethical implications. Cybersecurity remains a critical battleground, as we see novel threats countered by increasingly sophisticated defense strategies. Meanwhile, the Metaverse and Web3 are evolving, with ongoing developments in decentralized web functionalities and immersive digital spaces hinting at future applications and user adoption trends.
#
# **Health Headlines Shaping Our Future:** The biotech sector is abuzz with significant discoveries in gene editing and personalized medicine, promising a revolution in how we approach healthcare. Public health agencies are closely monitoring global trends, from infectious disease dynamics to the persistent influence of lifestyle on chronic conditions. Complementing this, wellness tech innovations, including advanced wearables and AI diagnostics, are empowering individuals to proactively manage their health.
#
# **Finance Focus: Markets & Money Matters:** Keep a close eye on key economic indicators like inflation data and interest rate decisions, which are currently shaping global markets. The investment landscape is dynamic, with emerging opportunities and shifts in asset class performance demanding attention. Additionally, stay informed on financial policy and regulatory updates that could impact businesses and your personal finances.
#
# The confluence of technology, health, and finance creates a complex but exciting ecosystem. By staying informed on these daily shifts, you're better equipped to navigate challenges, seize opportunities, and make smarter decisions in both your personal and professional life. Let this briefing be your compass in the ever-changing currents of innovation and progress.
# EditorAgent > ## The Daily Dose: Tech, Health, & Finance Insights You Can't Afford to Miss
#
# In today's fast-paced world, staying informed is paramount. But with information overload, finding the crucial updates that impact your life and work can be challenging. This daily briefing cuts through the noise, delivering essential news from the dynamic realms of technology, health, and finance.
#
# ### Tech Trends to Track
#
# *   **AI's Next Frontier:** Generative AI continues its rapid ascent, with new creative tools emerging and intensifying discussions around its industry-wide impact and ethical implications.
# *   **Cybersecurity at the Forefront:** Cybersecurity remains a critical battleground, as novel threats are met with increasingly sophisticated defense strategies.
# *   **The Metaverse & Web3 Evolution:** The Metaverse and Web3 are evolving, with ongoing developments in decentralized web functionalities and immersive digital spaces hinting at future applications and user adoption trends.
#
# ### Health Headlines Shaping Our Future
#
# *   **Breakthroughs in Biotech:** The biotech sector is abuzz with significant discoveries in gene editing and personalized medicine, promising a revolution in how we approach healthcare.
# *   **Public Health Pulse Check:** Public health agencies are closely monitoring global trends, from infectious disease dynamics to the persistent influence of lifestyle on chronic conditions.
# *   **Wellness Tech Innovations:** Wellness tech innovations, including advanced wearables and AI diagnostics, are empowering individuals to proactively manage their health.
#
# ### Finance Focus: Markets & Money Matters
#
# *   **Economic Indicators to Watch:** Keep a close eye on key economic indicators like inflation data and interest rate decisions, which are currently shaping global markets.
# *   **Investment Landscape Shifts:** The investment landscape is dynamic, with emerging opportunities and shifts in asset class performance demanding attention.
# *   **Financial Policy & Regulation Updates:** Stay informed on financial policy and regulatory updates that could impact businesses and your personal finances.
#
# The confluence of technology, health, and finance creates a complex but exciting ecosystem. By staying informed on these daily shifts, you'll be better equipped to navigate challenges, seize opportunities, and make smarter decisions in both your personal and professional life. Let this briefing be your compass in the ever-changing currents of innovation and progress.

# %% [markdown]
# ---
# ## ➰ Section 5: Loop Workflows - The Refinement Cycle
#
# **The Problem: One-Shot Quality**
#
# All the workflows we've seen so far run from start to finish. The `SequentialAgent` and `ParallelAgent` produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.
#
# **The Solution: Iterative Refinement**
#
# When a task needs to be improved through cycles of feedback and revision, you can use a `LoopAgent`. A `LoopAgent` runs a set of sub-agents repeatedly *until a specific condition is met or a maximum number of iterations is reached.* This creates a refinement cycle, allowing the agent system to improve its own work over and over.
#
# **Use Loop when:** Iterative improvement is needed, quality refinement matters, or you need repeated cycles.
#
# To learn more, check out the documentation related to [loop agents in ADK](https://google.github.io/adk-docs/agents/workflow-agents/loop-agents/).
#
# **Architecture: Story Writing & Critique Loop**
#
# ```mermaid
# graph TD
#     A["Initial Prompt"] --> B["Writer Agent"]
#     B -->|story| C["Critic Agent"]
#     C -->|critique| D{"Iteration < Max<br>AND<br>Not Approved?"}
#     D -->|Yes| B
#     D -->|No| E["Final Story"]
#
#     style B fill:#ccffcc
#     style C fill:#ffcccc
#     style D fill:#ffffcc
# ```

# %% [markdown]
# ### 5.1 Example: Iterative Story Refinement
#
# Let's build a system with two agents:
#
# 1. **Writer Agent** - Writes a draft of a short story
# 2. **Critic Agent** - Reviews and critiques the short story to suggest improvements

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# OutlineAgent > ## Blog Outline:
#
# **Headline:** The Keeper's Glow: A Lighthouse and a Map to the Unknown
#
# **Introduction Hook:** The rhythmic sweep of the lighthouse beam was the only constant in Silas's solitary life. But one stormy night, a glint of otherworldly light from a washed-up artifact would forever alter the familiar horizon.
#
# **Main Sections:**
#
# *   **Section 1: The Keeper's Solitude and the Storm's Gift**
#     *   Describe Silas's isolated existence, his routines, and his deep connection to the lighthouse.
#     *   Detail the ferocity of the storm and how it deposited the strange, luminous object on the shore.
#     *   Introduce the initial discovery of the map, emphasizing its unusual texture and faint glow.
#
# *   **Section 2: Unraveling the Luminous Lines**
#     *   Silas's initial fascination and cautious examination of the map.
#     *   The map's impossible geography – shifting constellations, landmasses that shouldn't exist.
#     *   The growing realization that the glowing lines are not static but react to Silas's touch and the lighthouse's beam.
#
# *   **Section 3: The Map's Whisper and the Beckoning Horizon**
#     *   The map begins to reveal faint sounds or impressions, hints of places or events.
#     *   Silas's internal struggle between his duty to the lighthouse and the irresistible pull of the map's mysteries.
#     *   A specific glowing symbol or path on the map that seems to indicate a destination.
#
# *   **Section 4: A Leap of Faith (Optional - depending on story length)**
#     *   Silas makes a decision – to follow the map or to dismiss it as a delusion.
#     *   If he decides to follow, what is his first step? A hidden cove, a coded message?
#     *   The subtle changes in the lighthouse or the environment as Silas engages with the map.
#
# **Concluding Thought:** The sea holds more secrets than any chart can contain, and sometimes, the most profound journeys begin not with a compass, but with a faint, ethereal glow pointing towards the horizon of the impossible.
# WriterAgent > ## The Keeper's Glow: A Lighthouse and a Map to the Unknown
#
# The rhythmic sweep of the lighthouse beam was the only constant in Silas's solitary life. For decades, his world was the towering stone structure, the salty air, and the predictable cycle of lamp maintenance. His deep connection to the lighthouse was more than professional; it was his anchor. But one stormy night, the ocean, usually a predictable adversary, delivered something entirely new. The ferocity of the gale battered the coast, and amidst the wreckage, a glint of otherworldly light caught Silas's eye. Washed ashore was a strange artifact, its surface impossibly smooth, its faint glow pulsing like a captured star.
#
# Cautiously, Silas brought the object inside. It unrolled to reveal a map, unlike any he had ever seen. Its texture was like cool, spun moonlight, and its lines shimmered with an internal luminescence. This was no ordinary chart. The geography was impossible, constellations shifted overhead, and landmasses appeared where only ocean should be. As Silas traced a glowing line with a trembling finger, he felt a subtle warmth, and the line pulsed brighter. He realized the map wasn't static; it reacted to him, and to the very beam of his lighthouse, which now seemed to cast an unusual light upon it.
#
# Then, the map began to whisper. Not in audible words, but in impressions, fleeting images of hidden coves and star-dusted skies. A specific symbol, a swirling vortex of light, began to glow more intensely, beckoning him. Silas felt a profound internal struggle. His duty was here, to the light, to the ships. Yet, this map, this impossible artifact, promised a horizon beyond his wildest dreams. The glowing symbol pulsed, a silent invitation to an unknown sea. The sea holds more secrets than any chart can contain, and sometimes, the most profound journeys begin not with a compass, but with a faint, ethereal glow pointing towards the horizon of the impossible.
# EditorAgent > The rhythmic sweep of the lighthouse beam was the only constant in Silas's solitary life. For decades, his world was the towering stone structure, the salty air, and the predictable cycle of lamp maintenance. This deep connection to the lighthouse was more than professional; it was his anchor. But one stormy night, the ocean, usually a predictable adversary, delivered something entirely new. The ferocity of the gale battered the coast, and amidst the wreckage, a glint of otherworldly light caught Silas's eye. Washed ashore was a strange artifact, its surface impossibly smooth, its faint glow pulsing like a captured star.
#
# Cautiously, Silas brought the object inside. It unrolled to reveal a map, unlike any he had ever seen. Its texture felt like cool, spun moonlight, and its lines shimmered with an internal luminescence. This was no ordinary chart. The geography was impossible, constellations shifted overhead, and landmasses appeared where only ocean should be. As Silas traced a glowing line with a trembling finger, he felt a subtle warmth, and the line pulsed brighter. He realized the map wasn't static; it reacted to him, and to the very beam of his lighthouse, which now seemed to cast an unusual light upon it.
#
# Then, the map began to whisper. Not in audible words, but in impressions—fleeting images of hidden coves and star-dusted skies. A specific symbol, a swirling vortex of light, began to glow more intensely, beckoning him. Silas felt a profound internal struggle. His duty was here, to the light, to the ships. Yet, this map, this impossible artifact, promised a horizon beyond his wildest dreams. The glowing symbol pulsed, a silent invitation to an unknown sea. The sea holds more secrets than any chart can contain, and sometimes, the most profound journeys begin not with a compass, but with a faint, ethereal glow pointing towards the horizon of the impossible.

# %% [markdown]
# ---
# ## Section 6: Summary - Choosing the Right Pattern
#
# ### Decision Tree: Which Workflow Pattern?
#
#
# ```mermaid
# graph TD
#     A{"What kind of workflow do you need?"} --> B["Fixed Pipeline<br>(A → B → C)"];
#     A --> C["Concurrent Tasks<br>(Run A, B, C all at once)"];
#     A --> D["Iterative Refinement<br>(A ⇆ B)"];
#     A --> E["Dynamic Decisions<br>(Let the LLM decide what to do)"];
#
#     B --> B_S["Use <b>SequentialAgent</b>"];
#     C --> C_S["Use <b>ParallelAgent</b>"];
#     D --> D_S["Use <b>LoopAgent</b>"];
#     E --> E_S["Use <b>LLM Orchestrator</b><br>(Agent with other agents as tools)"];
#
#     style B_S fill:#f9f,stroke:#333,stroke-width:2px
#     style C_S fill:#ccf,stroke:#333,stroke-width:2px
#     style D_S fill:#cff,stroke:#333,stroke-width:2px
#     style E_S fill:#cfc,stroke:#333,stroke-width:2px

# %% [markdown]
# ### Quick Reference Table
#
# | Pattern | When to Use | Example | Key Feature |
# |---------|-------------|---------|-------------|
# | **LLM-based (sub_agents)** | Dynamic orchestration needed | Research + Summarize | LLM decides what to call |
# | **Sequential** | Order matters, linear pipeline | Outline → Write → Edit | Deterministic order |
# | **Parallel** | Independent tasks, speed matters | Multi-topic research | Concurrent execution |
# | **Loop** | Iterative improvement needed | Writer + Critic refinement | Repeated cycles |
